# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week10/37_SNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edges_from([
    ('A', 'B'),
    ('A', 'C'),
    ('B', 'C'),
    ('B', 'D'),
    ('C', 'E'),
    ('D', 'E')
])
nx.draw(G, with_labels=True, node_color='lightblue', node_size=1000)
plt.show()
print("Degree Centrality:")
print(nx.degree_centrality(G))
print("\nCloseness Centrality:")
print(nx.closeness_centrality(G))
print("\nBetweenness Centrality:")
print(nx.betweenness_centrality(G))
# Out:
# Degree Centrality:
# {'A': 0.5, 'B': 0.75, 'C': 0.75, 'D': 0.5, 'E': 0.5}
#
# Closeness Centrality:
# {'A': 0.6666666666666666, 'B': 0.8, 'C': 0.8, 'D': 0.6666666666666666, 'E': 0.6666666666666666}
#
# Betweenness Centrality:
# {'A': 0.0, 'B': 0.25, 'C': 0.25, 'D': 0.08333333333333333, 'E': 0.08333333333333333}
