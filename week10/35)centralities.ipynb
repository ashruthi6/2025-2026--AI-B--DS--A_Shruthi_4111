# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week10/35)centralities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #35.write a code to import the networkx library and draw a graph with edges and point the centralities

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_edges_from([("A","B"),("A","C"),("B","C"),("B","D")])
nx.draw(G,with_labels=True)
plt.show()
print("Degree centrality:",nx.degree_centrality(G))
print("Betweenness centrality:",nx.betweenness_centrality(G))
print("Closeness centrality:",nx.closeness_centrality(G))
# Out:
# Degree centrality: {'A': 0.6666666666666666, 'B': 1.0, 'C': 0.6666666666666666, 'D': 0.3333333333333333}
# Betweenness centrality: {'A': 0.0, 'B': 0.6666666666666666, 'C': 0.0, 'D': 0.0}
# Closeness centrality: {'A': 0.75, 'B': 1.0, 'C': 0.75, 'D': 0.6}
