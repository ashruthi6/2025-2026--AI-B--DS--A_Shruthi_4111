# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week6/23)linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #23)write a code to implement linear regression on any sample dataset

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
#dataset
x=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([30,35,50,55,65])
#create model
model=LinearRegression()
model.fit(x,y)
#predict values
prediction=model.predict(x)
#print slop and intercept
print("slope:",model.coef_)
print("intercept",model.intercept_)
#plot graph
plt.scatter(x,y)
plt.plot(x,prediction)
plt.xlabel("expreience")
plt.ylabel("salary")
plt.title("Linear Regression")
plt.show()
# Out:
# slope: [9.]
# intercept 19.999999999999993
