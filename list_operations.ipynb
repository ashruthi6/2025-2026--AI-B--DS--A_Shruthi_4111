# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/list_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Creating lists
nums = [1, 2, 3, 4, 5]
mixed = [1, "hello", 3.5, True]
empty = []

print("Original list:", nums)

# 2. Accessing elements
print("First element:", nums[0])
print("Last element:", nums[-1])

# 3. Slicing
print("Slice [1:4]:", nums[1:4])
print("Slice [:3]:", nums[:3])
print("Slice [::2]:", nums[::2])

# 4. Modifying elements
nums[0] = 10
print("After modification:", nums)

# 5. Adding elements
nums.append(6)
print("After append:", nums)

nums.insert(1, 20)
print("After insert:", nums)

nums.extend([7, 8, 9])
print("After extend:", nums)

# 6. Removing elements
nums.remove(20)
print("After remove:", nums)

popped = nums.pop()
print("After pop:", nums, "| Popped:", popped)

nums.pop(0)
print("After pop at index 0:", nums)

# 7. Deleting elements
del nums[1]
print("After del:", nums)

# 8. Clearing list (using copy)
temp = nums.copy()
temp.clear()
print("After clear:", temp)

# 9. Searching
print("Index of 4:", nums.index(4))
print("Count of 3:", nums.count(3))

# 10. Sorting
nums.sort()
print("Sorted:", nums)

nums.sort(reverse=True)
print("Reverse sorted:", nums)

# 11. Reversing
nums.reverse()
print("Reversed:", nums)

# 12. Copying
copy1 = nums.copy()
copy2 = list(nums)
print("Copies:", copy1, copy2)

# 13. Length
print("Length:", len(nums))

# 14. Iteration
print("Looping through list:")
for item in nums:
    print(item)

# 15. List comprehension
squares = [x * x for x in nums]
print("Squares:", squares)

# 16. Nested lists
matrix = [[1, 2], [3, 4], [5, 6]]
print("Nested list:", matrix)
print("Access nested element:", matrix[0][1])

# 17. Min, Max, Sum
print("Min:", min(nums))
print("Max:", max(nums))
print("Sum:", sum(nums))

# 18. Joining list elements
words = ["Python", "is", "fun"]
sentence = " ".join(words)
print("Joined string:", sentence)
# Out:
# Original list: [1, 2, 3, 4, 5]
# First element: 1
# Last element: 5
# Slice [1:4]: [2, 3, 4]
# Slice [:3]: [1, 2, 3]
# Slice [::2]: [1, 3, 5]
# After modification: [10, 2, 3, 4, 5]
# After append: [10, 2, 3, 4, 5, 6]
# After insert: [10, 20, 2, 3, 4, 5, 6]
# After extend: [10, 20, 2, 3, 4, 5, 6, 7, 8, 9]
# After remove: [10, 2, 3, 4, 5, 6, 7, 8, 9]
# After pop: [10, 2, 3, 4, 5, 6, 7, 8] | Popped: 9
# After pop at index 0: [2, 3, 4, 5, 6, 7, 8]
# After del: [2, 4, 5, 6, 7, 8]
# After clear: []
# Index of 4: 1
# Count of 3: 0
# Sorted: [2, 4, 5, 6, 7, 8]
# Reverse sorted: [8, 7, 6, 5, 4, 2]
# Reversed: [2, 4, 5, 6, 7, 8]
# Copies: [2, 4, 5, 6, 7, 8] [2, 4, 5, 6, 7, 8]
# Length: 6
# Looping through list:
# 2
# 4
# 5
# 6
# 7
# 8
# Squares: [4, 16, 25, 36, 49, 64]
# Nested list: [[1, 2], [3, 4], [5, 6]]
# Access nested element: 2
# Min: 2
# Max: 8
# Sum: 32
# Joined string: Python is fun
