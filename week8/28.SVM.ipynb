# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week8/28.SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #28.write the code to implement support vector machine(SVM)

# %%
from sklearn import svm
x=[[2,2],[4,4],[2,0],[0,2]]
y=[1,1,-1,-1]
model=svm.SVC(kernel='linear')
model.fit(x,y)
print("model prediction:",model.predict([[2,0]]))
# Out:
# model prediction: [-1]
