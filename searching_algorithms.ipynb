# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/searching_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Linear Search

n = int(input("enter no. of elements:"))
arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i}:")))

key = int(input("enter element to search:"))

found = False

for i in range(n):
    if arr[i] == key:
        print(f"element {key} found at position {i+1}")
        found = True
        break

if not found:
    print("element not found:")
# Out:
# enter no. of elements:5
# enter element 0:1
# enter element 1:12
# enter element 2:4
# enter element 3:8
# enter element 4:7
# enter element to search:12
# element 12 found at position 2

# %%
# Binary Search

n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

arr.sort()
print("\n sorted list : arr")

key = int(input("enter element to search:"))

low = 0
high = n-1

found = False
while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        print(f"element {key} found at position {mid+1}")
        found = True
        break

    elif key < arr[mid]:
        high = mid - 1
# Out:
# enter number of elements:5
# enter element 1:4
# enter element 2:7
# enter element 3:6
# enter element 4:9
# enter element 5:3
#
#  sorted list : arr
# enter element to search:3
# element 3 found at position 1
