# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week5/22)hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #22.write a code to test for hypothesis,if test for Z is accepted or rejected

# %%
import math

n=100
x=50

p_hat=x/n

SE=math.sqrt(p_hat*(1-p_hat)/n)

z=1.96

lower=p_hat-z*SE
upper=p_hat+z*SE

print("Sample proportion=",p_hat)
print("Confidence interval=",(lower,upper))

p0=0.50

z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)

print("Test Statistic:",z_test)

if abs(z_test)>1.96:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Sample proportion= 0.5
# Confidence interval= (0.402, 0.598)
# Test Statistic: 0.0
# Accept null hypothesis
