# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week5/21)operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #21.write the code to perform the following opeartions
# 1.   z_score
# 2.  statistical inference
# 3.  random variable
# 4.   central limit theorem
# 5.   standradizations

# %%
#Z_score
import numpy as np

data=[10,20,30,40,50]

mean=np.mean(data)
print("Mean:",mean)

std_dev=np.std(data,ddof=0)
print("Standard deviation:",std_dev)

x=30

z_score=(x-mean)/std_dev
print("z-score of 30:",z_score)

z_scores=[(x-mean)/std_dev for x in data]
print("z-scores:",z_scores)
# Out:
# Mean: 30.0
# Standard deviation: 14.142135623730951
# z-score of 30: 0.0
# z-scores: [np.float64(-1.414213562373095), np.float64(-0.7071067811865475), np.float64(0.0), np.float64(0.7071067811865475), np.float64(1.414213562373095)]

# %%
#B)statistical inference,C)random variable D)central limit theorem E)standardizations
import numpy as np
import math
import matplotlib.pyplot as plt

population=np.array([10,20,30,40,50,60,70])

N=len(population)
print("Population Size(N):",N)

mu=np.mean(population)
print("Population mean:",mu)

sigma2=np.var(population,ddof=0)
print("Population variance:",sigma2)

sigma=math.sqrt(sigma2)
print("Population standard deviation:",sigma)

sample=np.array([20,30,40,50])

n=len(sample)
print("Sample Size(n):",n)

x_bar=np.mean(sample)
print("Sample mean:",x_bar)

s2=np.var(sample,ddof=0)
print("Sample variance:",s2)

s=math.sqrt(s2)
print("Sample standard deviation:",s)

SE=sigma/math.sqrt(n)
print("Standard Error:",SE)

z=(x_bar-mu)/SE
print("Z-score:",z)

num_samples=1000
sample_size=4

sample_means=[]

for i in range(num_samples):
    samp=np.random.choice(population,sample_size,replace=True)
    sample_means.append(np.mean(samp))

sample_means=np.array(sample_means)

print("Mean of sample means:",np.mean(sample_means))
print("Std of sample means:",np.std(sample_means))

plt.hist(sample_means,bins=20,edgecolor='black')
plt.title("Central Limit Theorem: Distribution of Sample Means")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()
# Out:
# Population Size(N): 7
# Population mean: 40.0
# Population variance: 400.0
# Population standard deviation: 20.0
# Sample Size(n): 4
# Sample mean: 35.0
# Sample variance: 125.0
# Sample standard deviation: 11.180339887498949
# Standard Error: 10.0
# Z-score: -0.5
# Mean of sample means: 40.28
# Std of sample means: 10.192968164376852
