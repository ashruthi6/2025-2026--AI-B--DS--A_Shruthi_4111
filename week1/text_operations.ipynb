# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week1/text_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q4:Write the code to create, save and read the file from the local drive to perform the text operations ( count number of lines, words and characters)**
# **DATE:03/02/2026**

# %%
# Step 1: Create and write to a file
file_name = "sample_text.txt"

with open(file_name, "w") as file:
    file.write("Hello World\n")
    file.write("This is a Python file\n")
    file.write("We are counting lines, words and characters\n")

print("File created and data written successfully!")

# Step 2: Read the file
with open(file_name, "r") as file:
    text = file.read()

print("\nFile Content:")
print(text)

# Step 3: Count number of lines
lines = text.split("\n")
line_count = len(lines)

# Step 4: Count number of words
words = text.split()
word_count = len(words)

# Step 5: Count number of characters
char_count = len(text)

# Step 6: Display results
print("\nNumber of lines:", line_count)
print("Number of words:", word_count)
print("Number of characters:", char_count)
# Out:
# File created and data written successfully!
#
# File Content:
# Hello World
# This is a Python file
# We are counting lines, words and characters
#
#
# Number of lines: 4
# Number of words: 14
# Number of characters: 78
