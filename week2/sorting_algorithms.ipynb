# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/sorting_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Selection sort
n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# selection sort logic
for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # swap found min element with first element
    arr[i], arr[min_index] = arr[min_index], arr[i]

print("sorted array:", arr)
# Out:
# enter number of elements:5
# enter element 1:1
# enter element 2:7
# enter element 3:6
# enter element 4:10
# enter element 5:4
#
#  Original array: [1, 7, 6, 10, 4]
# sorted array: [1, 4, 6, 7, 10]

# %%
# Bubble sort
n = int(input("enter num of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# Bubble sort logic
for i in range(n-1):
    for j in range(n-1-i):
        if arr[j] > arr[j+1]:
            # Swap
            arr[j], arr[j+1] = arr[j+1], arr[j]

print("Sorted array:", arr)
# Out:
# enter num of elements:5
# enter element 1:4
# enter element 2:3
# enter element 3:9
# enter element 4:6
# enter element 5:7
#
#  Original array: [4, 3, 9, 6, 7]
# Sorted array: [3, 4, 6, 7, 9]

# %%
# Insertion Sort

n = int(input("enter num of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Insertion sort logic
for i in range(1, n):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] > key:
        arr[j+1] = arr[j]
        j -= 1

    arr[j+1] = key

print("Sorted array:", arr)
# Out:
# enter num of elements: 5
# enter element 1: 6
# enter element 2: 7
# enter element 3: 3
# enter element 4: 2
# enter element 5: 1
#
# Original array: [6, 7, 3, 2, 1]
# Sorted array: [1, 2, 3, 6, 7]
