# %% [markdown]
# <a href="https://colab.research.google.com/github/ashruthi6/2025-2026--AI-B--DS--A_Shruthi_4111/blob/main/week4/20)data_distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #20.Perform the following operations on data distributions
#
# a. Normal distribution
#
# b. Left skewness
#
# c. Right skewness

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(5)

normal_data = np.random.normal(loc=70, scale=5, size=1000)

right_skewed = np.random.exponential(scale=10, size=1000)

left_skewed = -np.random.exponential(scale=10, size=1000)

plt.hist(normal_data, bins=30)
plt.title("Normal Distribution")
plt.show()

plt.hist(right_skewed, bins=30)
plt.title("Right Skewed Distribution")
plt.show()

plt.hist(left_skewed, bins=30)
plt.title("Left Skewed Distribution")
plt.show()

print("Normal Mean:", np.mean(normal_data))
print("Normal Median:", np.median(normal_data))

print("Right Skewed Mean:", np.mean(right_skewed))
print("Right Skewed Median:", np.median(right_skewed))

print("Left Skewed Mean:", np.mean(left_skewed))
print("Left Skewed Median:", np.median(left_skewed))
# Out:
# Normal Mean: 70.16638513946428
# Normal Median: 70.11862802044882
# Right Skewed Mean: 10.193325576778399
# Right Skewed Median: 7.132417828071522
# Left Skewed Mean: -9.801474810325857
# Left Skewed Median: -6.708502466833851
